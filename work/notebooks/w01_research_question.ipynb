# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sonukumae/FlyRank-AI-machine-learning-internship/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
### My Lane

#I chose the **Content Refresh** lane. My goal is to identify pages that may benefit from being updated based on signals such as content age, impressions, CTR, and average position. This lane is useful because refreshing high-potential pages can improve search performance and help prioritize SEO work.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
### Research Question

#My work helps decide which pages should be refreshed first. The SEO team or content team would use these recommendations to prioritize updates. A wrong recommendation could waste time updating pages that do not need changes or miss pages that have greater improvement potential.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os

for root, dirs, files in os.walk("/content"):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# /content/FlyRank-AI-machine-learning-internship/data/raw/content_refresh_anonymized.csv
# /content/FlyRank-AI-machine-learning-internship/FlyRank-AI-machine-learning-internship/data/raw/content_refresh_anonymized.csv
# /content/FlyRank-AI-machine-learning-internship/FlyRank-AI-machine-learning-internship/outputs/refresh_queue_sample.csv
# /content/FlyRank-AI-machine-learning-internship/outputs/refresh_queue_sample.csv
# /content/sample_data/mnist_train_small.csv
# /content/sample_data/mnist_test.csv
# /content/sample_data/california_housing_train.csv
# /content/sample_data/california_housing_test.csv

# %%
import pandas as pd

df = pd.read_csv("/content/FlyRank-AI-machine-learning-internship/data/raw/content_refresh_anonymized.csv")

df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
import pandas as pd

df = pd.read_csv("/content/FlyRank-AI-machine-learning-internship/data/raw/content_refresh_anonymized.csv")

print("Number of rows:", len(df))
print("Number of columns:", len(df.columns))

print("\nAverage CTR:", round(df["ctr"].mean(), 2))
print("Average Position:", round(df["avg_position"].mean(), 2))
print("Average Search Volume:", round(df["search_volume"].mean(), 2))
# Out:
# Number of rows: 30000
# Number of columns: 44
#
# Average CTR: 0.51
# Average Position: 16.34
# Average Search Volume: 158.88

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
### What I can and cannot claim

#This work provides decision support based on observed patterns in the available data. Any relationships found are directional and should not be interpreted as proof of cause and effect. This project does not predict Google's ranking algorithm or guarantee that refreshing a page will improve performance.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
